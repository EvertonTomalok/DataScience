# %%
from nltk import word_tokenize
from collections import namedtuple

# %%
word_context = namedtuple("WordContext", "words_before words_after target_word")

# %%
class Cbow:
    def __init__(self, text: str, context_window: int=1):
        self._text = text
        self._tokens = word_tokenize(text)
        self._len_tokens = len(self._tokens)
        self._context_window = context_window
        
    @property
    def text(self):
        return self._text
    
    @property
    def len_tokens(self):
        return self._len_tokens
    
    @property
    def tokens(self):
        return self._tokens
    
    @property
    def context_window(self):
        return self._context_window
    
    def get_context_words(self):
        word_list = [] 

        for index, word in enumerate(self.tokens):
            if index - self.context_window < 0:
                continue
            elif index + self.context_window == self.len_tokens:
                break
                
            word_list.append(
                word_context(
                    self.get_tokens_before(index),
                    self.get_tokens_after(index),
                    self.tokens[index]
                )
            )
            
        return word_list
    
    def get_tokens_before(self, index):
        w = []
        i = 0
        while i < self.context_window:
            i += 1
            w.append(self.tokens[index - i])
            
        return list(reversed(w))
    
    def get_tokens_after(self, index):
        w = []
        i = 0
        while i < self.context_window:
            i += 1
            w.append(self.tokens[index + i])
            
        return w
    
    def __repr__(self):
        return str(self.tokens)

# %%
texto_dom_casmurro = "Publicado pela primeira vez em 1899, “Dom Casmurro” é uma das grandes obras de Machado de Assis e confirma o olhar certeiro e crítico que o autor estendia sobre toda a sociedade brasileira. Também a temática do ciúme, abordada com brilhantismo nesse livro, provoca polêmicas em torno do caráter de uma das principais personagens femininas da literatura brasileira: Capitu."

cbow = Cbow(texto_dom_casmurro, context_window=1)

# %%
cbow
# Out:
# ['Publicado', 'pela', 'primeira', 'vez', 'em', '1899', ',', '“', 'Dom', 'Casmurro', '”', 'é', 'uma', 'das', 'grandes', 'obras', 'de', 'Machado', 'de', 'Assis', 'e', 'confirma', 'o', 'olhar', 'certeiro', 'e', 'crítico', 'que', 'o', 'autor', 'estendia', 'sobre', 'toda', 'a', 'sociedade', 'brasileira', '.', 'Também', 'a', 'temática', 'do', 'ciúme', ',', 'abordada', 'com', 'brilhantismo', 'nesse', 'livro', ',', 'provoca', 'polêmicas', 'em', 'torno', 'do', 'caráter', 'de', 'uma', 'das', 'principais', 'personagens', 'femininas', 'da', 'literatura', 'brasileira', ':', 'Capitu', '.']

# %%
cbow.get_context_words()
# Out:
# [WordContext(words_before=['Publicado'], words_after=['primeira'], target_word='pela'),
#  WordContext(words_before=['pela'], words_after=['vez'], target_word='primeira'),
#  WordContext(words_before=['primeira'], words_after=['em'], target_word='vez'),
#  WordContext(words_before=['vez'], words_after=['1899'], target_word='em'),
#  WordContext(words_before=['em'], words_after=[','], target_word='1899'),
#  WordContext(words_before=['1899'], words_after=['“'], target_word=','),
#  WordContext(words_before=[','], words_after=['Dom'], target_word='“'),
#  WordContext(words_before=['“'], words_after=['Casmurro'], target_word='Dom'),
#  WordContext(words_before=['Dom'], words_after=['”'], target_word='Casmurro'),
#  WordContext(words_before=['Casmurro'], words_after=['é'], target_word='”'),
#  WordContext(words_before=['”'], words_after=['uma'], target_word='é'),
#  WordContext(words_before=['é'], words_after=['das'], target_word='uma'),
#  WordContext(words_before=['uma'], words_after=['grandes'], target_word='das'),
#  WordContext(words_before=['das'], words_after=['obras'], target_word='grandes'),
#  WordContext(words_before=['grandes'], words_after=['de'], target_word='obras'),
#  WordContext(words_before=['obras'], words_after=['Machado'], target_word='de'),
#  WordContext(words_before=['de'], words_after=['de'], target_word='Machado'),
#  WordContext(words_before=['Machado'], words_after=['Assis'], target_word='de'),
#  WordContext(words_before=['de'], words_after=['e'], target_word='Assis'),
#  WordContext(words_before=['Assis'], words_after=['confirma'], target_word='e'),
#  WordContext(words_before=['e'], words_after=['o'], target_word='confirma'),
#  WordContext(words_before=['confirma'], words_after=['olhar'], target_word='o'),
#  WordContext(words_before=['o'], words_after=['certeiro'], target_word='olhar'),
#  WordContext(words_before=['olhar'], words_after=['e'], target_word='certeiro'),
#  WordContext(words_before=['certeiro'], words_after=['crítico'], target_word='e'),
#  WordContext(words_before=['e'], words_after=['que'], target_word='crítico'),
#  WordContext(words_before=['crítico'], words_after=['o'], target_word='que'),
#  WordContext(words_before=['que'], words_after=['autor'], target_word='o'),
#  WordContext(words_before=['o'], words_after=['estendia'], target_word='autor'),
#  WordContext(words_before=['autor'], words_after=['sobre'], target_word='estendia'),
#  WordContext(words_before=['estendia'], words_after=['toda'], target_word='sobre'),
#  WordContext(words_before=['sobre'], words_after=['a'], target_word='toda'),
#  WordContext(words_before=['toda'], words_after=['sociedade'], target_word='a'),
#  WordContext(words_before=['a'], words_after=['brasileira'], target_word='sociedade'),
#  WordContext(words_before=['sociedade'], words_after=['.'], target_word='brasileira'),
#  WordContext(words_before=['brasileira'], words_after=['Também'], target_word='.'),
#  WordContext(words_before=['.'], words_after=['a'], target_word='Também'),
#  WordContext(words_before=['Também'], words_after=['temática'], target_word='a'),
#  WordContext(words_before=['a'], words_after=['do'], target_word='temática'),
#  WordContext(words_before=['temática'], words_after=['ciúme'], target_word='do'),
#  WordContext(words_before=['do'], words_after=[','], target_word='ciúme'),
#  WordContext(words_before=['ciúme'], words_after=['abordada'], target_word=','),
#  WordContext(words_before=[','], words_after=['com'], target_word='abordada'),
#  WordContext(words_before=['abordada'], words_after=['brilhantismo'], target_word='com'),
#  WordContext(words_before=['com'], words_after=['nesse'], target_word='brilhantismo'),
#  WordContext(words_before=['brilhantismo'], words_after=['livro'], target_word='nesse'),
#  WordContext(words_before=['nesse'], words_after=[','], target_word='livro'),
#  WordContext(words_before=['livro'], words_after=['provoca'], target_word=','),
#  WordContext(words_before=[','], words_after=['polêmicas'], target_word='provoca'),
#  WordContext(words_before=['provoca'], words_after=['em'], target_word='polêmicas'),
#  WordContext(words_before=['polêmicas'], words_after=['torno'], target_word='em'),
#  WordContext(words_before=['em'], words_after=['do'], target_word='torno'),
#  WordContext(words_before=['torno'], words_after=['caráter'], target_word='do'),
#  WordContext(words_before=['do'], words_after=['de'], target_word='caráter'),
#  WordContext(words_before=['caráter'], words_after=['uma'], target_word='de'),
#  WordContext(words_before=['de'], words_after=['das'], target_word='uma'),
#  WordContext(words_before=['uma'], words_after=['principais'], target_word='das'),
#  WordContext(words_before=['das'], words_after=['personagens'], target_word='principais'),
#  WordContext(words_before=['principais'], words_after=['femininas'], target_word='personagens'),
#  WordContext(words_before=['personagens'], words_after=['da'], target_word='femininas'),
#  WordContext(words_before=['femininas'], words_after=['literatura'], target_word='da'),
#  WordContext(words_before=['da'], words_after=['brasileira'], target_word='literatura'),
#  WordContext(words_before=['literatura'], words_after=[':'], target_word='brasileira'),
#  WordContext(words_before=['brasileira'], words_after=['Capitu'], target_word=':'),
#  WordContext(words_before=[':'], words_after=['.'], target_word='Capitu')]

# %%
for infos in cbow.get_context_words():
    print(infos)
    print("=============\n")
    print("Target word: %s" % infos.target_word)
    print("Words before: %s" % infos.words_before)
    print("Words after: %s" % infos.words_after)
    print()
# Out:
# WordContext(words_before=['Publicado'], words_after=['primeira'], target_word='pela')
# =============
#
# Target word: pela
# Words before: ['Publicado']
# Words after: ['primeira']
#
# WordContext(words_before=['pela'], words_after=['vez'], target_word='primeira')
# =============
#
# Target word: primeira
# Words before: ['pela']
# Words after: ['vez']
#
# WordContext(words_before=['primeira'], words_after=['em'], target_word='vez')
# =============
#
# Target word: vez
# Words before: ['primeira']
# Words after: ['em']
#
# WordContext(words_before=['vez'], words_after=['1899'], target_word='em')
# =============
#
# Target word: em
# Words before: ['vez']
# Words after: ['1899']
#
# WordContext(words_before=['em'], words_after=[','], target_word='1899')
# =============
#
# Target word: 1899
# Words before: ['em']
# Words after: [',']
#
# WordContext(words_before=['1899'], words_after=['“'], target_word=',')
# =============
#
# Target word: ,
# Words before: ['1899']
# Words after: ['“']
#
# WordContext(words_before=[','], words_after=['Dom'], target_word='“')
# =============
#
# Target word: “
# Words before: [',']
# Words after: ['Dom']
#
# WordContext(words_before=['“'], words_after=['Casmurro'], target_word='Dom')
# =============
#
# Target word: Dom
# Words before: ['“']
# Words after: ['Casmurro']
#
# WordContext(words_before=['Dom'], words_after=['”'], target_word='Casmurro')
# =============
#
# Target word: Casmurro
# Words before: ['Dom']
# Words after: ['”']
#
# WordContext(words_before=['Casmurro'], words_after=['é'], target_word='”')
# =============
#
# Target word: ”
# Words before: ['Casmurro']
# Words after: ['é']
#
# WordContext(words_before=['”'], words_after=['uma'], target_word='é')
# =============
#
# Target word: é
# Words before: ['”']
# Words after: ['uma']
#
# WordContext(words_before=['é'], words_after=['das'], target_word='uma')
# =============
#
# Target word: uma
# Words before: ['é']
# Words after: ['das']
#
# WordContext(words_before=['uma'], words_after=['grandes'], target_word='das')
# =============
#
# Target word: das
# Words before: ['uma']
# Words after: ['grandes']
#
# WordContext(words_before=['das'], words_after=['obras'], target_word='grandes')
# =============
#
# Target word: grandes
# Words before: ['das']
# Words after: ['obras']
#
# WordContext(words_before=['grandes'], words_after=['de'], target_word='obras')
# =============
#
# Target word: obras
# Words before: ['grandes']
# Words after: ['de']
#
# WordContext(words_before=['obras'], words_after=['Machado'], target_word='de')
# =============
#
# Target word: de
# Words before: ['obras']
# Words after: ['Machado']
#
# WordContext(words_before=['de'], words_after=['de'], target_word='Machado')
# =============
#
# Target word: Machado
# Words before: ['de']
# Words after: ['de']
#
# WordContext(words_before=['Machado'], words_after=['Assis'], target_word='de')
# =============
#
# Target word: de
# Words before: ['Machado']
# Words after: ['Assis']
#
# WordContext(words_before=['de'], words_after=['e'], target_word='Assis')
# =============
#
# Target word: Assis
# Words before: ['de']
# Words after: ['e']
#
# WordContext(words_before=['Assis'], words_after=['confirma'], target_word='e')
# =============
#
# Target word: e
# Words before: ['Assis']
# Words after: ['confirma']
#
# WordContext(words_before=['e'], words_after=['o'], target_word='confirma')
# =============
#
# Target word: confirma
# Words before: ['e']
# Words after: ['o']
#
# WordContext(words_before=['confirma'], words_after=['olhar'], target_word='o')
# =============
#
# Target word: o
# Words before: ['confirma']
# Words after: ['olhar']
#
# WordContext(words_before=['o'], words_after=['certeiro'], target_word='olhar')
# =============
#
# Target word: olhar
# Words before: ['o']
# Words after: ['certeiro']
#
# WordContext(words_before=['olhar'], words_after=['e'], target_word='certeiro')
# =============
#
# Target word: certeiro
# Words before: ['olhar']
# Words after: ['e']
#
# WordContext(words_before=['certeiro'], words_after=['crítico'], target_word='e')
# =============
#
# Target word: e
# Words before: ['certeiro']
# Words after: ['crítico']
#
# WordContext(words_before=['e'], words_after=['que'], target_word='crítico')
# =============
#
# Target word: crítico
# Words before: ['e']
# Words after: ['que']
#
# WordContext(words_before=['crítico'], words_after=['o'], target_word='que')
# =============
#
# Target word: que
# Words before: ['crítico']
# Words after: ['o']
#
# WordContext(words_before=['que'], words_after=['autor'], target_word='o')
# =============
#
# Target word: o
# Words before: ['que']
# Words after: ['autor']
#
# WordContext(words_before=['o'], words_after=['estendia'], target_word='autor')
# =============
#
# Target word: autor
# Words before: ['o']
# Words after: ['estendia']
#
# WordContext(words_before=['autor'], words_after=['sobre'], target_word='estendia')
# =============
#
# Target word: estendia
# Words before: ['autor']
# Words after: ['sobre']
#
# WordContext(words_before=['estendia'], words_after=['toda'], target_word='sobre')
# =============
#
# Target word: sobre
# Words before: ['estendia']
# Words after: ['toda']
#
# WordContext(words_before=['sobre'], words_after=['a'], target_word='toda')
# =============
#
# Target word: toda
# Words before: ['sobre']
# Words after: ['a']
#
# WordContext(words_before=['toda'], words_after=['sociedade'], target_word='a')
# =============
#
# Target word: a
# Words before: ['toda']
# Words after: ['sociedade']
#
# WordContext(words_before=['a'], words_after=['brasileira'], target_word='sociedade')
# =============
#
# Target word: sociedade
# Words before: ['a']
# Words after: ['brasileira']
#
# WordContext(words_before=['sociedade'], words_after=['.'], target_word='brasileira')
# =============
#
# Target word: brasileira
# Words before: ['sociedade']
# Words after: ['.']
#
# WordContext(words_before=['brasileira'], words_after=['Também'], target_word='.')
# =============
#
# Target word: .
# Words before: ['brasileira']
# Words after: ['Também']
#
# WordContext(words_before=['.'], words_after=['a'], target_word='Também')
# =============
#
# Target word: Também
# Words before: ['.']
# Words after: ['a']
#
# WordContext(words_before=['Também'], words_after=['temática'], target_word='a')
# =============
#
# Target word: a
# Words before: ['Também']
# Words after: ['temática']
#
# WordContext(words_before=['a'], words_after=['do'], target_word='temática')
# =============
#
# Target word: temática
# Words before: ['a']
# Words after: ['do']
#
# WordContext(words_before=['temática'], words_after=['ciúme'], target_word='do')
# =============
#
# Target word: do
# Words before: ['temática']
# Words after: ['ciúme']
#
# WordContext(words_before=['do'], words_after=[','], target_word='ciúme')
# =============
#
# Target word: ciúme
# Words before: ['do']
# Words after: [',']
#
# WordContext(words_before=['ciúme'], words_after=['abordada'], target_word=',')
# =============
#
# Target word: ,
# Words before: ['ciúme']
# Words after: ['abordada']
#
# WordContext(words_before=[','], words_after=['com'], target_word='abordada')
# =============
#
# Target word: abordada
# Words before: [',']
# Words after: ['com']
#
# WordContext(words_before=['abordada'], words_after=['brilhantismo'], target_word='com')
# =============
#
# Target word: com
# Words before: ['abordada']
# Words after: ['brilhantismo']
#
# WordContext(words_before=['com'], words_after=['nesse'], target_word='brilhantismo')
# =============
#
# Target word: brilhantismo
# Words before: ['com']
# Words after: ['nesse']
#
# WordContext(words_before=['brilhantismo'], words_after=['livro'], target_word='nesse')
# =============
#
# Target word: nesse
# Words before: ['brilhantismo']
# Words after: ['livro']
#
# WordContext(words_before=['nesse'], words_after=[','], target_word='livro')
# =============
#
# Target word: livro
# Words before: ['nesse']
# Words after: [',']
#
# WordContext(words_before=['livro'], words_after=['provoca'], target_word=',')
# =============
#
# Target word: ,
# Words before: ['livro']
# Words after: ['provoca']
#
# WordContext(words_before=[','], words_after=['polêmicas'], target_word='provoca')
# =============
#
# Target word: provoca
# Words before: [',']
# Words after: ['polêmicas']
#
# WordContext(words_before=['provoca'], words_after=['em'], target_word='polêmicas')
# =============
#
# Target word: polêmicas
# Words before: ['provoca']
# Words after: ['em']
#
# WordContext(words_before=['polêmicas'], words_after=['torno'], target_word='em')
# =============
#
# Target word: em
# Words before: ['polêmicas']
# Words after: ['torno']
#
# WordContext(words_before=['em'], words_after=['do'], target_word='torno')
# =============
#
# Target word: torno
# Words before: ['em']
# Words after: ['do']
#
# WordContext(words_before=['torno'], words_after=['caráter'], target_word='do')
# =============
#
# Target word: do
# Words before: ['torno']
# Words after: ['caráter']
#
# WordContext(words_before=['do'], words_after=['de'], target_word='caráter')
# =============
#
# Target word: caráter
# Words before: ['do']
# Words after: ['de']
#
# WordContext(words_before=['caráter'], words_after=['uma'], target_word='de')
# =============
#
# Target word: de
# Words before: ['caráter']
# Words after: ['uma']
#
# WordContext(words_before=['de'], words_after=['das'], target_word='uma')
# =============
#
# Target word: uma
# Words before: ['de']
# Words after: ['das']
#
# WordContext(words_before=['uma'], words_after=['principais'], target_word='das')
# =============
#
# Target word: das
# Words before: ['uma']
# Words after: ['principais']
#
# WordContext(words_before=['das'], words_after=['personagens'], target_word='principais')
# =============
#
# Target word: principais
# Words before: ['das']
# Words after: ['personagens']
#
# WordContext(words_before=['principais'], words_after=['femininas'], target_word='personagens')
# =============
#
# Target word: personagens
# Words before: ['principais']
# Words after: ['femininas']
#
# WordContext(words_before=['personagens'], words_after=['da'], target_word='femininas')
# =============
#
# Target word: femininas
# Words before: ['personagens']
# Words after: ['da']
#
# WordContext(words_before=['femininas'], words_after=['literatura'], target_word='da')
# =============
#
# Target word: da
# Words before: ['femininas']
# Words after: ['literatura']
#
# WordContext(words_before=['da'], words_after=['brasileira'], target_word='literatura')
# =============
#
# Target word: literatura
# Words before: ['da']
# Words after: ['brasileira']
#
# WordContext(words_before=['literatura'], words_after=[':'], target_word='brasileira')
# =============
#
# Target word: brasileira
# Words before: ['literatura']
# Words after: [':']
#
# WordContext(words_before=['brasileira'], words_after=['Capitu'], target_word=':')
# =============
#
# Target word: :
# Words before: ['brasileira']
# Words after: ['Capitu']
#
# WordContext(words_before=[':'], words_after=['.'], target_word='Capitu')
# =============
#
# Target word: Capitu
# Words before: [':']
# Words after: ['.']

# %%
cbow = Cbow(texto_dom_casmurro, context_window=5)
for infos in cbow.get_context_words():
    print("=============\n")
    print("Target word: %s" % infos.target_word)
    print("Words before: %s" % infos.words_before)
    print("Words after: %s" % infos.words_after)
    print()
# Out:
# =============
#
# Target word: 1899
# Words before: ['Publicado', 'pela', 'primeira', 'vez', 'em']
# Words after: [',', '“', 'Dom', 'Casmurro', '”']
#
# =============
#
# Target word: ,
# Words before: ['pela', 'primeira', 'vez', 'em', '1899']
# Words after: ['“', 'Dom', 'Casmurro', '”', 'é']
#
# =============
#
# Target word: “
# Words before: ['primeira', 'vez', 'em', '1899', ',']
# Words after: ['Dom', 'Casmurro', '”', 'é', 'uma']
#
# =============
#
# Target word: Dom
# Words before: ['vez', 'em', '1899', ',', '“']
# Words after: ['Casmurro', '”', 'é', 'uma', 'das']
#
# =============
#
# Target word: Casmurro
# Words before: ['em', '1899', ',', '“', 'Dom']
# Words after: ['”', 'é', 'uma', 'das', 'grandes']
#
# =============
#
# Target word: ”
# Words before: ['1899', ',', '“', 'Dom', 'Casmurro']
# Words after: ['é', 'uma', 'das', 'grandes', 'obras']
#
# =============
#
# Target word: é
# Words before: [',', '“', 'Dom', 'Casmurro', '”']
# Words after: ['uma', 'das', 'grandes', 'obras', 'de']
#
# =============
#
# Target word: uma
# Words before: ['“', 'Dom', 'Casmurro', '”', 'é']
# Words after: ['das', 'grandes', 'obras', 'de', 'Machado']
#
# =============
#
# Target word: das
# Words before: ['Dom', 'Casmurro', '”', 'é', 'uma']
# Words after: ['grandes', 'obras', 'de', 'Machado', 'de']
#
# =============
#
# Target word: grandes
# Words before: ['Casmurro', '”', 'é', 'uma', 'das']
# Words after: ['obras', 'de', 'Machado', 'de', 'Assis']
#
# =============
#
# Target word: obras
# Words before: ['”', 'é', 'uma', 'das', 'grandes']
# Words after: ['de', 'Machado', 'de', 'Assis', 'e']
#
# =============
#
# Target word: de
# Words before: ['é', 'uma', 'das', 'grandes', 'obras']
# Words after: ['Machado', 'de', 'Assis', 'e', 'confirma']
#
# =============
#
# Target word: Machado
# Words before: ['uma', 'das', 'grandes', 'obras', 'de']
# Words after: ['de', 'Assis', 'e', 'confirma', 'o']
#
# =============
#
# Target word: de
# Words before: ['das', 'grandes', 'obras', 'de', 'Machado']
# Words after: ['Assis', 'e', 'confirma', 'o', 'olhar']
#
# =============
#
# Target word: Assis
# Words before: ['grandes', 'obras', 'de', 'Machado', 'de']
# Words after: ['e', 'confirma', 'o', 'olhar', 'certeiro']
#
# =============
#
# Target word: e
# Words before: ['obras', 'de', 'Machado', 'de', 'Assis']
# Words after: ['confirma', 'o', 'olhar', 'certeiro', 'e']
#
# =============
#
# Target word: confirma
# Words before: ['de', 'Machado', 'de', 'Assis', 'e']
# Words after: ['o', 'olhar', 'certeiro', 'e', 'crítico']
#
# =============
#
# Target word: o
# Words before: ['Machado', 'de', 'Assis', 'e', 'confirma']
# Words after: ['olhar', 'certeiro', 'e', 'crítico', 'que']
#
# =============
#
# Target word: olhar
# Words before: ['de', 'Assis', 'e', 'confirma', 'o']
# Words after: ['certeiro', 'e', 'crítico', 'que', 'o']
#
# =============
#
# Target word: certeiro
# Words before: ['Assis', 'e', 'confirma', 'o', 'olhar']
# Words after: ['e', 'crítico', 'que', 'o', 'autor']
#
# =============
#
# Target word: e
# Words before: ['e', 'confirma', 'o', 'olhar', 'certeiro']
# Words after: ['crítico', 'que', 'o', 'autor', 'estendia']
#
# =============
#
# Target word: crítico
# Words before: ['confirma', 'o', 'olhar', 'certeiro', 'e']
# Words after: ['que', 'o', 'autor', 'estendia', 'sobre']
#
# =============
#
# Target word: que
# Words before: ['o', 'olhar', 'certeiro', 'e', 'crítico']
# Words after: ['o', 'autor', 'estendia', 'sobre', 'toda']
#
# =============
#
# Target word: o
# Words before: ['olhar', 'certeiro', 'e', 'crítico', 'que']
# Words after: ['autor', 'estendia', 'sobre', 'toda', 'a']
#
# =============
#
# Target word: autor
# Words before: ['certeiro', 'e', 'crítico', 'que', 'o']
# Words after: ['estendia', 'sobre', 'toda', 'a', 'sociedade']
#
# =============
#
# Target word: estendia
# Words before: ['e', 'crítico', 'que', 'o', 'autor']
# Words after: ['sobre', 'toda', 'a', 'sociedade', 'brasileira']
#
# =============
#
# Target word: sobre
# Words before: ['crítico', 'que', 'o', 'autor', 'estendia']
# Words after: ['toda', 'a', 'sociedade', 'brasileira', '.']
#
# =============
#
# Target word: toda
# Words before: ['que', 'o', 'autor', 'estendia', 'sobre']
# Words after: ['a', 'sociedade', 'brasileira', '.', 'Também']
#
# =============
#
# Target word: a
# Words before: ['o', 'autor', 'estendia', 'sobre', 'toda']
# Words after: ['sociedade', 'brasileira', '.', 'Também', 'a']
#
# =============
#
# Target word: sociedade
# Words before: ['autor', 'estendia', 'sobre', 'toda', 'a']
# Words after: ['brasileira', '.', 'Também', 'a', 'temática']
#
# =============
#
# Target word: brasileira
# Words before: ['estendia', 'sobre', 'toda', 'a', 'sociedade']
# Words after: ['.', 'Também', 'a', 'temática', 'do']
#
# =============
#
# Target word: .
# Words before: ['sobre', 'toda', 'a', 'sociedade', 'brasileira']
# Words after: ['Também', 'a', 'temática', 'do', 'ciúme']
#
# =============
#
# Target word: Também
# Words before: ['toda', 'a', 'sociedade', 'brasileira', '.']
# Words after: ['a', 'temática', 'do', 'ciúme', ',']
#
# =============
#
# Target word: a
# Words before: ['a', 'sociedade', 'brasileira', '.', 'Também']
# Words after: ['temática', 'do', 'ciúme', ',', 'abordada']
#
# =============
#
# Target word: temática
# Words before: ['sociedade', 'brasileira', '.', 'Também', 'a']
# Words after: ['do', 'ciúme', ',', 'abordada', 'com']
#
# =============
#
# Target word: do
# Words before: ['brasileira', '.', 'Também', 'a', 'temática']
# Words after: ['ciúme', ',', 'abordada', 'com', 'brilhantismo']
#
# =============
#
# Target word: ciúme
# Words before: ['.', 'Também', 'a', 'temática', 'do']
# Words after: [',', 'abordada', 'com', 'brilhantismo', 'nesse']
#
# =============
#
# Target word: ,
# Words before: ['Também', 'a', 'temática', 'do', 'ciúme']
# Words after: ['abordada', 'com', 'brilhantismo', 'nesse', 'livro']
#
# =============
#
# Target word: abordada
# Words before: ['a', 'temática', 'do', 'ciúme', ',']
# Words after: ['com', 'brilhantismo', 'nesse', 'livro', ',']
#
# =============
#
# Target word: com
# Words before: ['temática', 'do', 'ciúme', ',', 'abordada']
# Words after: ['brilhantismo', 'nesse', 'livro', ',', 'provoca']
#
# =============
#
# Target word: brilhantismo
# Words before: ['do', 'ciúme', ',', 'abordada', 'com']
# Words after: ['nesse', 'livro', ',', 'provoca', 'polêmicas']
#
# =============
#
# Target word: nesse
# Words before: ['ciúme', ',', 'abordada', 'com', 'brilhantismo']
# Words after: ['livro', ',', 'provoca', 'polêmicas', 'em']
#
# =============
#
# Target word: livro
# Words before: [',', 'abordada', 'com', 'brilhantismo', 'nesse']
# Words after: [',', 'provoca', 'polêmicas', 'em', 'torno']
#
# =============
#
# Target word: ,
# Words before: ['abordada', 'com', 'brilhantismo', 'nesse', 'livro']
# Words after: ['provoca', 'polêmicas', 'em', 'torno', 'do']
#
# =============
#
# Target word: provoca
# Words before: ['com', 'brilhantismo', 'nesse', 'livro', ',']
# Words after: ['polêmicas', 'em', 'torno', 'do', 'caráter']
#
# =============
#
# Target word: polêmicas
# Words before: ['brilhantismo', 'nesse', 'livro', ',', 'provoca']
# Words after: ['em', 'torno', 'do', 'caráter', 'de']
#
# =============
#
# Target word: em
# Words before: ['nesse', 'livro', ',', 'provoca', 'polêmicas']
# Words after: ['torno', 'do', 'caráter', 'de', 'uma']
#
# =============
#
# Target word: torno
# Words before: ['livro', ',', 'provoca', 'polêmicas', 'em']
# Words after: ['do', 'caráter', 'de', 'uma', 'das']
#
# =============
#
# Target word: do
# Words before: [',', 'provoca', 'polêmicas', 'em', 'torno']
# Words after: ['caráter', 'de', 'uma', 'das', 'principais']
#
# =============
#
# Target word: caráter
# Words before: ['provoca', 'polêmicas', 'em', 'torno', 'do']
# Words after: ['de', 'uma', 'das', 'principais', 'personagens']
#
# =============
#
# Target word: de
# Words before: ['polêmicas', 'em', 'torno', 'do', 'caráter']
# Words after: ['uma', 'das', 'principais', 'personagens', 'femininas']
#
# =============
#
# Target word: uma
# Words before: ['em', 'torno', 'do', 'caráter', 'de']
# Words after: ['das', 'principais', 'personagens', 'femininas', 'da']
#
# =============
#
# Target word: das
# Words before: ['torno', 'do', 'caráter', 'de', 'uma']
# Words after: ['principais', 'personagens', 'femininas', 'da', 'literatura']
#
# =============
#
# Target word: principais
# Words before: ['do', 'caráter', 'de', 'uma', 'das']
# Words after: ['personagens', 'femininas', 'da', 'literatura', 'brasileira']
#
# =============
#
# Target word: personagens
# Words before: ['caráter', 'de', 'uma', 'das', 'principais']
# Words after: ['femininas', 'da', 'literatura', 'brasileira', ':']
#
# =============
#
# Target word: femininas
# Words before: ['de', 'uma', 'das', 'principais', 'personagens']
# Words after: ['da', 'literatura', 'brasileira', ':', 'Capitu']
#
# =============
#
# Target word: da
# Words before: ['uma', 'das', 'principais', 'personagens', 'femininas']
# Words after: ['literatura', 'brasileira', ':', 'Capitu', '.']
